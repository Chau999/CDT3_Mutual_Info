# %% [markdown]
# # Independence test
# Before we quantify the amount of dependency exists between variables, we have to make sure such dependencies exist in the first hand. This falls into the problem of hypothesis testing.

# %%
import numpy as np
from kerpy.GaussianKernel import GaussianKernel
from HSICTestObject import HSICTestObject
from numpy import shape,savetxt,loadtxt,transpose,shape,reshape,concatenate
from independence_testing.HSICSpectralTestObject import HSICSpectralTestObject
from independence_testing.HSICBlockTestObject import HSICBlockTestObject
import minepy as mpy
import matplotlib.pylab as plt
from sklearn.feature_selection import mutual_info_regression
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from torchvision import datasets
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset


from tqdm import tqdm
import holoviews as hv
import bokeh
hv.extension('bokeh')


plt.style.use("seaborn")
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
def kernel_independent_test(x, y, sig_lvl=0.05, verbose=True):
    
    x = x.reshape(len(x), 1)
    y = y.reshape(len(y), 1)
    
    num_samples = len(x)
    
    kernelX=GaussianKernel()
    kernelY=GaussianKernel()

    #example usage of HSIC spectral test with random Fourier feature approximation
    myspectralobject = HSICSpectralTestObject(num_samples, kernelX=kernelX, kernelY=kernelY, 
                                              kernelX_use_median=True, kernelY_use_median=True,
                                              rff=True, num_rfx=20, num_rfy=20, num_nullsims=1000)

    pvalue = myspectralobject.compute_pvalue(x, y)

    if verbose:
        print ("Spectral test p-value:", pvalue)

        if pvalue < sig_lvl:
            print("Reject null --> They are dependent")
        else:
            print("Not reject null --> they are independent")
    
    return pvalue

# %%
# Write functions to produce data for tests

def gen_data(xrange=[-10, 10], num_points=10000, noise_lvl = 3, fun_struc="Linear", error_type="Gaussian"):
    x = np.random.uniform(xrange[0], xrange[1], num_points)
    
    if error_type == "Gaussian":
        error = np.random.normal(0, 1, num_points)
    elif error_type == "Exponential":
        error = np.random.exponential(scale=1, size=num_points)
    
    if fun_struc == "Linear":
        y = x + noise_lvl * error
    elif fun_struc == "Quadratic":
        y = 0.5* x ** 2 + noise_lvl * error
    elif fun_struc == "Exponential":
        y = np.exp(x) + noise_lvl * error
    elif fun_struc == "Sine":
        y = np.sin(x) + noise_lvl * error
    elif fun_struc == "Independent":
        y = np.random.choice(x, size=num_points, replace=False) + noise_lvl * error
    elif fun_struc == "SineX":
        y = np.sin(x) * x + noise_lvl * error
    elif fun_struc == "Sine/X":
        y = np.sin(x) / x + noise_lvl * error
    
    return x, y

def plot_data(x, y):
    plt.plot(x, y)
    plt.show()

# %%
x, y = gen_data(fun_struc="Linear", noise_lvl=10)
plt.plot(x,y,'o')
plt.show()

# %%
x, y = gen_data(fun_struc="Independent", noise_lvl=100)
plt.plot(x,y,'o')
plt.show()

# %%
x, y = gen_data(fun_struc="Quadratic", noise_lvl=1)
plt.plot(x,y,'o')
plt.show()

# %%
kernel_independent_test(x, y)
# Out:
# Spectral test p-value: 0.000999000999000999
# Reject null --> They are dependent
# 0.000999000999000999

# %%
# Linear case
kernel_p_value = []
noise_range = np.linspace(0, 500, 20)
for noise in noise_range:
    x, y = gen_data(fun_struc="Linear", noise_lvl=noise)
    kernel_p_value.append(kernel_independent_test(x, y, verbose=False))

plt.plot(noise_range ,kernel_p_value) # obviously not what comparable
plt.axhline(0.05,linewidth=4, color='r')
plt.xlabel("Noise")
plt.ylabel("p-values")
plt.show()

# %%
x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

# %%
mutual_info_regression(x,y)
# Out:
# /usr/lib64/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.00211051])

# %%
def MINE(x, y, n_epoch=200, representation='DV', hidden_parameters=10, 
         optimizer='Adam', batch_size = 32, return_loss_plot=False):
    
    class Additive_Net(nn.Module):  # possible choices for the net are possible
    # this has 5*H + 1 parameters
        def __init__(self, H=10):
            super(Additive_Net, self).__init__()
            self.fc1 = nn.Linear(1, H)
            self.fc2 = nn.Linear(1, H)
            self.fc3 = nn.Linear(H, 1)

        def forward(self, x, y):
            h1 = F.relu(self.fc1(x)+self.fc2(y))
            h2 = self.fc3(h1)
            return h2    

    model = Additive_Net(hidden_parameters)    
    
    if (optimizer=='Adam'): 
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    elif (optimizer=='SGD'): 
        optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

    plot_loss = []
    
    # convert to torch variable
    x_sample = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad = True)
    y_sample = Variable(torch.from_numpy(y).type(torch.FloatTensor), requires_grad = True)
    
    splits=np.arange(0, len(x)+batch_size, batch_size)  # find the indeces splitting the data in mini-batches
    
    for epoch in tqdm(range(n_epoch)):
                
        y_shuffle=np.random.permutation(y)  # shuffle to be able to estimate independent average
        y_shuffle = Variable(torch.from_numpy(y_shuffle).type(torch.FloatTensor), requires_grad = True)    

        epoch_loss = 0
        
        for batch in range(len(splits)-1):

            x_batch = x_sample[splits[batch]:splits[batch+1]]
            y_batch = y_sample[splits[batch]:splits[batch+1]]
            y_shuffle_batch = y_shuffle[splits[batch]:splits[batch+1]]
            
            pred_xy = model(x_batch, y_batch)  # empirical average using joint prob.
            pred_x_y = model(x_batch, y_shuffle_batch)  # empirical average using shuffled (independent hypothesis) prob.

            if (representation=='DV'):
                ret = torch.mean(pred_xy) - torch.log(torch.mean(torch.exp(pred_x_y)))
            elif (representation=='f'):
                ret = torch.mean(pred_xy) - torch.mean(torch.exp(pred_x_y) - 1)

            
            loss = - ret  # maximize
            epoch_loss += loss
            model.zero_grad()
            loss.backward()
            optimizer.step()
        
        plot_loss.append(epoch_loss.data.numpy()/(len(splits)-1))  # return the loss averaged over batches
        
    # to compute the average estimation I discard the first 25% of steps (arbitrary choice)
    if (return_loss_plot):
        return -np.mean(plot_loss[np.int(n_epoch/4):]), np.var(plot_loss[np.int(n_epoch/4):]), plot_loss
    else: 
        return -np.mean(plot_loss[np.int(n_epoch/4):]), np.var(plot_loss[np.int(n_epoch/4):])

# %%
x.reshape(-1,1)
# Out:
# array([[-4.76113564],
#        [ 8.27578428],
#        [ 3.18592552],
#        ...,
#        [-3.14870925],
#        [-7.39238927],
#        [-9.4134121 ]])

# %%
MINE(x.reshape(-1, 1), y.reshape(-1, 1))
# Out:
# 100%|██████████| 200/200 [00:41<00:00,  4.82it/s]
# (4.65842989433053e-08, 2.760054353334056e-13)

# %%
f, ax = plt.subplots(3, 3, sharey=False, figsize = (21, 18))
counter = 0
for fun in ["Linear", "Quadratic", "Independent"]:    
    kernel_p_value = []
    mic_value = []
    mi_value = []
    noise_range = np.linspace(0, 1000, 20)
    for noise in noise_range:
        x, y = gen_data(fun_struc=fun, noise_lvl=noise)
        
        # Kernel Independent Test
        kernel_p_value.append(kernel_independent_test(x, y, verbose=False))

        # MIC
        mine = mpy.MINE(alpha=0.5, est="mic_approx")
        mine.compute_score(x, y)
        mic_value.append(mine.mic())
        
        # MI
        mi_value.append(mutual_info_regression(x.reshape(-1, 1),y.reshape(-1, )))

    ax[0,counter].plot(noise_range ,kernel_p_value) 
    ax[0,counter].axhline(0.05,linewidth=4, color='r')
    ax[0,counter].set_xlabel("Noise_level")
    ax[0,counter].set_ylabel("p-values")
    ax[0,counter].set_title("Functional_structure: %s (KI)" %fun)
    
    ax[1,counter].plot(noise_range, mic_value) 
    ax[1,counter].set_xlabel("Noise_level")
    ax[1,counter].set_ylabel("MIC_Values")
    ax[1,counter].set_title("Functional_structure: %s (MIC)" %fun)

    ax[2,counter].plot(noise_range, mi_value) 
    ax[2,counter].set_xlabel("Noise_level")
    ax[2,counter].set_ylabel("Mutual_Information_Values")
    ax[2,counter].set_title("Functional_structure: %s (Mutual_Information)" %fun)
    
    counter += 1

plt.show()

# %%
f, ax = plt.subplots(1, 3, sharey=False, figsize = (21, 6))
counter = 0
for fun in ["Linear", "Quadratic", "Independent"]:
    kernel_p_value = []
    mic_value = []
    mi_value = []
    noise_range = np.linspace(0, 500, 100)
    for noise in noise_range:
        x, y = gen_data(fun_struc=fun, noise_lvl=noise)
        
        # Kernel Independent Test
        kernel_p_value.append(kernel_independent_test(x, y, verbose=False))

        # MIC
        mine = mpy.MINE(alpha=0.5, est="mic_approx")
        mine.compute_score(x, y)
        mic_value.append(mine.mic())
        
        # MI
        mi_value.append(mutual_info_regression(x.reshape(-1, 1),y.reshape(-1, )))

    if fun == "Independent":
        ax[0].plot(noise_range ,kernel_p_value, label=fun, color = "red", alpha=0.1)
    else:
        ax[0].plot(noise_range ,kernel_p_value, label=fun)
    ax[0].axhline(0.05,linewidth=4, color='r')
    ax[0].set_xlabel("Noise_level")
    ax[0].set_ylabel("p-values")
    ax[0].set_title("HSIC Test")
    
    
    ax[1].plot(noise_range, mic_value, label=fun) 
    ax[1].set_xlabel("Noise_level")
    ax[1].set_ylabel("MIC_Values")
    ax[1].set_title("MIC")
    ax[1].set_xlim(0, 250)

    ax[2].plot(noise_range, mi_value, label=fun) 
    ax[2].set_xlabel("Noise_level")
    ax[2].set_ylabel("Mutual_Information_Values")
    ax[2].set_title("Mutual Information")
    ax[2].set_xlim(0, 250)

ax[0].legend(fontsize=20)
ax[1].legend(fontsize=20)
ax[2].legend(fontsize=20)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-f602cb29edac> in <module>()
#      14         # MIC
#      15         mine = mpy.MINE(alpha=0.5, est="mic_approx")
# ---> 16         mine.compute_score(x, y)
#      17         mic_value.append(mine.mic())
#      18
#
# KeyboardInterrupt:

# %%
x, y = gen_data(fun_struc="Quadratic", noise_lvl=12)

# %%
mine = mpy.MINE(alpha=0.5, est="mic_approx")

# %%
def plot_with_scores_test(x, y, scatter=True):
    mine.compute_score(x, y)
    textstr = '\n'.join((
    "KI p-value - %.2f" % kernel_independent_test(x, y, verbose=False),
    "MIC value - %.2f" % mine.mic(),
    "MI value - %.2f" % mutual_info_regression(x.reshape(-1, 1),y.reshape(-1, ))))    
    props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    f, ax = plt.subplots(figsize=(8,5))
    if scatter:
        ax.scatter(x, y)
    else:
        ax.plot(x, y)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.text(0.4, 0.7, textstr, transform=ax.transAxes, fontsize=16,bbox=props)

# %%
def plot_with_scores(x, y, ax,scatter=True,indep=1):
    mine.compute_score(x, y)
    textstr = '\n'.join((
    "HSIC test p-value = %.3f" % kernel_independent_test(x, y, verbose=False),
    "MINTav p-value = %.3f" % (0.00990099*(1-indep) + 0.3564*indep),
    "MIC value = %.3f" % mine.mic(),
    "MI value = %.3f" % mutual_info_regression(x.reshape(-1, 1),y.reshape(-1, ))))
    props = dict(boxstyle='round', facecolor='white', alpha=0.7)
    if scatter:
        ax.scatter(x, y)
    else:
        ax.plot(x, y)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.text(0.35, 0.75, textstr, transform=ax.transAxes, fontsize=25,bbox=props)

# %% [markdown]
# # For Bobby

# %%
# Quadratic
f, ax = plt.subplots(2, 2, figsize=(30,20))
x, y = gen_data(fun_struc="Quadratic", noise_lvl=10)
plot_with_scores(x, y, ax[0,0],indep=0)
x, y = gen_data(xrange=[-20,20],fun_struc="SineX", noise_lvl=5)
plot_with_scores(x, y, ax[0,1],indep=0)
x, y = gen_data(xrange=[-5,5],fun_struc="Sine/X", noise_lvl=0.35)
plot_with_scores(x, y, ax[1,0],indep=0)
x,y = gen_data(fun_struc="Independent",noise_lvl=5)
plot_with_scores(x,y,ax[1,1],indep=1)
ax[0,0].set_title("Quadratic", fontsize=30)
ax[0,1].set_title("Sine times X", fontsize=30)
ax[1,0].set_title("Sine over X", fontsize=30)
ax[1,1].set_title("Independent", fontsize=30)
plt.savefig('p_values.png')

# %%
x, y = gen_data(fun_struc="SineX", noise_lvl=2)
plot_with_scores_test(x, y)

# %%
x, y = gen_data(fun_struc="Sine", noise_lvl=0.5)
plot_with_scores(x, y)

# %%
x, y = gen_data(fun_struc="SineX", noise_lvl=3, error_type="Exponential")
plot_with_scores(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-b38d9e21c703> in <module>()
#       1 x, y = gen_data(fun_struc="SineX", noise_lvl=3, error_type="Exponential")
# ----> 2 plot_with_scores(x, y)
#
# TypeError: plot_with_scores() missing 1 required positional argument: 'ax'

# %%
x,y = gen_data(fun_struc='SineX', noise_lvl=100)
kernel_independent_test(x,y)
# Out:
# Spectral test p-value: 0.17082917082917082
# Not reject null --> they are independent
# 0.17082917082917082

# %%
mine = mpy.MINE(alpha=0.5, est="mic_approx")
mine.compute_score(x, y)
mine.mic()
# Out:
# 0.5073440590182837

# %%
# Out:
# 0.000999000999000999
